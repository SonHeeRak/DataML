# %%
import requests
import lxml.html

# 네이버 영화평 주소
url = 'http://movie.naver.com/movie/point/af/list.nhn?target=after$page={}'

res = requests.get(url.format(1))
element = lxml.html.fromstring(res.text)

# 리뷰 총 개수
total = int(element.find('.//strong[@class="c_88 fs_11"]').text_content())
# 총 페이지수
total_page = int(total / 10)
total_page

# 리뷰 모음
reviews = []

# 크롤링 코드
for page in range(1, total_page+1):
    res = requests.get(url.format(page))
    element = lxml.html.fromstring(res.text)
    # HTML 요소 분석을 통해 작성한 코드
    # table.list_netizen 테이블의 tbody > tr > td.point, td.title을 분석하는 코드
    for e in element.xpath('.//table[@class="list_netizen"]//tbody//tr'):
        star = e.find('.//td[@class="point"]').text_content()
        comment = e.find('.//td[@class="title"]').text_content()
        comment = comment.strip().replace("\t", "").replace("\r", "").split("\n")
        title = comment[0]
        reple = comment[4]
        reviews.append([title, star, reple])
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\envs\kaggle\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\envs\kaggle\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11002] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\envs\kaggle\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~\Anaconda3\envs\kaggle\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1253         """Send a complete request to the server."""
# -> 1254         self._send_request(method, url, body, headers, encode_chunked)
#    1255
#
# ~\Anaconda3\envs\kaggle\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1299             body = _encode(body, 'body')
# -> 1300         self.endheaders(body, encode_chunked=encode_chunked)
#    1301
#
# ~\Anaconda3\envs\kaggle\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1248             raise CannotSendHeader()
# -> 1249         self._send_output(message_body, encode_chunked=encode_chunked)
#    1250
#
# ~\Anaconda3\envs\kaggle\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#
# ~\Anaconda3\envs\kaggle\lib\http\client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\urllib3\connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x00000203A807A358>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\envs\kaggle\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPConnectionPool(host='movie.naver.com', port=80): Max retries exceeded with url: /movie/point/af/list.nhn?target=after$page=13067 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000203A807A358>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-228-e0d859d578db> in <module>
#      19 # 크롤링 코드
#      20 for page in range(1, total_page+1):
# ---> 21     res = requests.get(url.format(page))
#      22     element = lxml.html.fromstring(res.text)
#      23     # HTML 요소 분석을 통해 작성한 코드
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='movie.naver.com', port=80): Max retries exceeded with url: /movie/point/af/list.nhn?target=after$page=13067 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000203A807A358>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed',))

# %%
import pandas as pd

naver_review = pd.DataFrame(reviews)
naver_review.columns = ['title', 'point', 'comment']
naver_review
# Out:
#         title point                                            comment
# 0          변신     2  역겨운게 많아 보기힘들고 속이 너무 안좋네요웃으면서 나왔습니다.. 한영화에 여러 작...
# 1      47미터 2     2                                후반부로 갈수록 웃음만 나는 영화
# 2    유열의 음악앨범     8                            추억은 방울방울 ㆍ그시절 감성포텐 터지네
# 3    유열의 음악앨범     2              뭐야 이 댓글 알바 ㅅㄲ들 ㅡㅡ 비긴어게인만큼 말도 안되는 홍본가
# 4    유열의 음악앨범     1                                    별로였어요.. 내용이...
# ..        ...   ...                                                ...
# 985        변신    10                              이렇게 무섭게 만들면 반칙 아닌가요?
# 986  유열의 음악앨범     7                               간결한 서사 뻔한 플롯 모두의 청춘
# 987        변신    10                                  올해 공포영화 중에서는 대에박
# 988  유열의 음악앨범    10                          유희열의 음악앨범 마음이 힐링되는 기분입니다
# 989    47미터 2     1                                 진짜 개노잼이더라....알바들아
#
# [990 rows x 3 columns]
