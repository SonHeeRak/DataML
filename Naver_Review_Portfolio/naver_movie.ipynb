# %%
import requests
import lxml.html

# 네이버 영화평 주소
url = 'http://movie.naver.com/movie/point/af/list.nhn?target=after$page={}'

res = requests.get(url.format(1))
element = lxml.html.fromstring(res.text)

# 리뷰 총 개수
total = int(element.find('.//strong[@class="c_88 fs_11"]').text_content())
# 총 페이지수
total_page = int(total / 10)
total_page

# 리뷰 모음
reviews = []

# 크롤링 코드
for page in range(1, 1000):
    res = requests.get(url.format(page))
    element = lxml.html.fromstring(res.text)
    # HTML 요소 분석을 통해 작성한 코드
    # table.list_netizen 테이블의 tbody > tr > td.point, td.title을 분석하는 코드
    for e in element.xpath('.//table[@class="list_netizen"]//tbody//tr'):
        star = e.find('.//td[@class="point"]').text_content()
        comment = e.find('.//td[@class="title"]').text_content()
        comment = comment.strip().replace("\t", "").replace("\r", "").split("\n")
        title = comment[0]
        reple = comment[4]
        reviews.append([title, star, reple])

# %%
import pandas as pd

naver_review = pd.DataFrame(reviews)
naver_review.columns = ['title', 'point', 'comment']
naver_review
# Out:
#          title point                                            comment
# 0           변신    10                     진짜무서움ㅜ간만에집중하면서봤네요배우들 연기너무잘해요ㅠ
# 1     블라인드 멜로디    10                           마지막 깡통 치는거에  뭔가 여운이  남음
# 2          엑시트     9  솔직히 별로 기대 안하고 봤는데  윤아가 연기를 이렇게 잘하는지 몰랐네요.  캐스팅...
# 3       47미터 2     9  재밌었음 놀랄 때도 있고 잘 만듦 예상되는 전개이긴 했는데, 감안하고 봐도 재밌었다...
# 4       47미터 2     2     도랐나. 제일 몸매좋은애부터 죽이면 우짜노..유일하게 그 부분만 보는데..하...
# ...        ...   ...                                                ...
# 9985     커런트 워     1  와...문화의날 방금 보고왔는데 영화보다가 잔건 2번째네...영화가 너무 잔잔하고 ...
# 9986  유열의 음악앨범     9       오그라드는 멜로 장르라 기대하지 않았다. 하지만 이상하게 무장해제되고 말았다.
# 9987  유열의 음악앨범    10                                     긴 여운이 남는 영화였다
# 9988       엑시트    10          클라이밍 배우고 싶게 만드는 영화 ㅋㅋㅋㅋ 누가 싫어요 테러하고 다니니~
# 9989        변신    10                     진짜무서움ㅜ간만에집중하면서봤네요배우들 연기너무잘해요ㅠ
#
# [9990 rows x 3 columns]
